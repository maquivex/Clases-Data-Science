# %% [markdown]
# # Data Set Precio Mobiles
#
# ## Samuel Quispe Valdivia

# %% [markdown]
# Importando Librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %run "/content/pandas_missing_extension.ipynb"

# %%
PATH_CSV = "/content/modiledatasetnew.csv"

# %%
df = pd.read_csv(PATH_CSV)
df
# Out:
#        brand  price  reting  is_5g  is_nfc  is_ir_blaster processor_brand  \
# 0    Samsung  74999    92.0      1       1              0      Snapdragon
# 1    Oneplus  24997    83.0      1       0              1       Dimensity
# 2      Apple  47999    81.0      1       1              0          Bionic
# 3     Realme  16999    82.0      1       0              0       Dimensity
# 4    Samsung  33890    84.0      1       1              0          Exynos
# ..       ...    ...     ...    ...     ...            ...             ...
# 906     Iqoo  27999    80.0      1       0              1      Snapdragon
# 907   Xiaomi  13980    80.0      0       0              1           Helio
# 908   Xiaomi  16499    84.0      1       0              1       Dimensity
# 909   Realme  27990    82.0      1       0              0       Dimensity
# 910     Vivo  43670    84.0      1       0              0       Dimensity
#
#      core  proccessor_speed  ram  internal_memory  battery_size  fast_charge  \
# ...

# %%
df["os"].value_counts()
# Out:
# os
# Android    871
# iOS         40
# Name: count, dtype: int64

# %%
df["brand"].value_counts()
# Out:
# brand
# Samsung     147
# Realme      129
# Vivo        119
# Oppo         82
# Xiaomi       63
# Motorola     57
# Poco         45
# Oneplus      45
# Apple        40
# Iqoo         38
# Infinix      30
# Lava         27
# Tecno        26
# Google       19
# Nothing      15
# Alcatel       5
# Hmd           5
# Honor         5
# Cmf           4
# Ai+           4
# Acer          3
# Itel          3
# Name: count, dtype: int64

# %%
df["processor_brand"].value_counts()
# Out:
# processor_brand
# Dimensity     393
# Snapdragon    326
# Exynos         58
# Bionic         40
# Unisoc         37
# Helio          36
# Tensor         19
# Tiger           2
# Name: count, dtype: int64

# %% [markdown]
# ## EDA ##

# %%
df.dtypes
# Out:
# brand                object
# price                 int64
# reting              float64
# is_5g                 int64
# is_nfc                int64
# is_ir_blaster         int64
# processor_brand      object
# core                  int64
# proccessor_speed    float64
# ram                   int64
# internal_memory       int64
# battery_size          int64
# fast_charge           int64
# charging_speed        int64
# rear_mp               int64
# front_mp              int64
# os                   object
# display_size        float64
# refresh_rate          int64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64      13
# object      3
# float64     3
# Name: count, dtype: int64

# %% [markdown]
# ## TRATAMIENTO DE NULOS ##

# %%
df.isnull().sum()
# Out:
# brand               0
# price               0
# reting              0
# is_5g               0
# is_nfc              0
# is_ir_blaster       0
# processor_brand     0
# core                0
# proccessor_speed    0
# ram                 0
# internal_memory     0
# battery_size        0
# fast_charge         0
# charging_speed      0
# rear_mp             0
# front_mp            0
# os                  0
# display_size        0
# refresh_rate        0
# dtype: int64

# %%
df.missing.number_missing()
# Out:
# np.int64(0)

# %%
df.missing.number_complete()
# Out:
# np.int64(17309)

# %%
df.missing.missing_variable_plot()

# %% [markdown]
# ## Eliminando campos que no son relevantes

# %%
df_cleaned = df.drop(columns=['reting', 'is_nfc', 'is_ir_blaster','fast_charge','charging_speed','refresh_rate'])
df_cleaned
# Out:
#        brand  price  is_5g processor_brand  core  proccessor_speed  ram  \
# 0    Samsung  74999      1      Snapdragon     8              3.30   12
# 1    Oneplus  24997      1       Dimensity     8              3.35    8
# 2      Apple  47999      1          Bionic     6              3.46    6
# 3     Realme  16999      1       Dimensity     8              2.40    6
# 4    Samsung  33890      1          Exynos    10              3.11    8
# ..       ...    ...    ...             ...   ...               ...  ...
# 906     Iqoo  27999      1      Snapdragon     8              3.20    8
# 907   Xiaomi  13980      0           Helio     8              2.05    8
# 908   Xiaomi  16499      1       Dimensity     8              2.40    6
# 909   Realme  27990      1       Dimensity     8              2.50    6
# 910     Vivo  43670      1       Dimensity     8              3.05    8
#
#      internal_memory  battery_size  rear_mp  front_mp       os  display_size
# ...

# %%
df_cleaned.to_csv('Mobiles_cleaned.csv',index=None)
